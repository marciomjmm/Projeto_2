# %% [markdown]
# # Desafio: Acompanhamento de Ações na Bolsa de Valores B3
#
# Uma empresa que gerencia investimentos na bolsa de valores B3 precisa desenvolver uma solução para monitorar o desempenho de ações ao longo de um período específico (ex.: semanal, mensal, trimestral). O objetivo é criar um sistema que permita a análise de dados históricos, comparando a performance de diferentes ativos, além de gerar relatórios e alertas para identificar oportunidades de compra e venda. O projeto deve incluir:
#
# - Coleta de Dados: Captura de dados de ações listadas na B3 (valores de abertura, fechamento, volume, etc.) através de APIs ou fontes de dados públicas.
#
# - Armazenamento: Organização dos dados históricos em uma base eficiente, possibilitando consultas rápidas.
#
# - Análise: Desenvolvimento de modelos analíticos para identificar tendências e padrões, bem como cálculo de indicadores financeiros como P/L, dividend yield, e volatilidade.
#
# - Visualização: Criação de dashboards e relatórios para monitorar os resultados e gerar insights sobre a performance das ações.
#
# - Alertas: Definição de critérios de alerta para notificar a equipe sobre variações anormais ou oportunidades de mercado.

# %% [markdown]
# ## Widgets

# %%
dbutils.widgets.text("acoes", "")
dbutils.widgets.text("data_inicial", "2023-01-01")
# dbutils.widgets.multiselect("media_movel","30",["10","30","60","90","120"])

# %%
filter_acoes = dbutils.widgets.get("acoes")
# filter_media_movel = dbutils.widgets.get("media_movel")
# filter_media_movel = ["10","30","60","90","120"]

# %% [markdown]
# ## Install

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Using cached yfinance-0.2.45-py2.py3-none-any.whl (100 kB)
# Requirement already satisfied: pandas>=1.3.0 in /databricks/python3/lib/python3.9/site-packages (from yfinance) (1.4.2)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from yfinance) (2.6.2)
# Collecting lxml>=4.9.1
#   Using cached lxml-5.3.0-cp39-cp39-manylinux_2_28_x86_64.whl (5.0 MB)
# Collecting requests>=2.31
#   Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Collecting multitasking>=0.0.7
#   Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Collecting pytz>=2022.5
#   Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Collecting frozendict>=2.3.4
#   Using cached frozendict-2.4.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (116 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /databricks/python3/lib/python3.9/site-packages (from yfinance) (4.11.1)
# Collecting html5lib>=1.1
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Collecting peewee>=3.16.2
#   Using cached peewee-3.17.7.tar.gz (939 kB)
# done
# error
#   ERROR: Command errored out with exit status 1:
#    command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmpke33zcbn
#        cwd: /tmp/pip-install-etsk6jlq/peewee_4430736f26ae4292bbe1a0dcf76f0b1c
#   Complete output (38 lines):
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#
#
#   # We define an xConnect function, but leave xCreate NULL so that the
#   # table-function can be called eponymously.
#   cdef int pwConnect(sqlite3 *db, void *pAux, int argc, const char *const*argv,
#                      sqlite3_vtab **ppVtab, char **pzErr) noexcept with gil:
#                                                          ^
#   ------------------------------------------------------------
#
#   playhouse/_sqlite_ext.pyx:389:56: Syntax error in C variable declaration
#   Compiling playhouse/_sqlite_ext.pyx because it depends on /databricks/python/lib/python3.9/site-packages/Cython/Includes/libc/string.pxd.
#   [1/1] Cythonizing playhouse/_sqlite_ext.pyx
#   Traceback (most recent call last):
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 349, in <module>
#       main()
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 331, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 117, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 177, in get_requires_for_build_wheel
#       return self._get_build_requires(
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 159, in _get_build_requires
#       self.run_setup()
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 174, in run_setup
#       exec(compile(code, __file__, 'exec'), locals())
#     File "setup.py", line 201, in <module>
#       _do_setup(extension_support, sqlite_extension_support)
#     File "setup.py", line 196, in _do_setup
#       ext_modules=cythonize(ext_modules))
#     File "/databricks/python/lib/python3.9/site-packages/Cython/Build/Dependencies.py", line 1127, in cythonize
#       cythonize_one(*args)
#     File "/databricks/python/lib/python3.9/site-packages/Cython/Build/Dependencies.py", line 1250, in cythonize_one
#       raise CompileError(None, pyx_file)
#   Cython.Compiler.Errors.CompileError: playhouse/_sqlite_ext.pyx
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/e1/2d/c5e34703c118da6dae4de89d5c9b5a2fb9fbc2f7789ac2c8d8836f6367ba/peewee-3.17.7.tar.gz#sha256=6aefc700bd530fc6ac23fa19c9c5b47041751d92985b799169c8e318e97eabaa (from https://pypi.org/simple/peewee/). Command errored out with exit status 1: /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmpke33zcbn Check the logs for full command output.
#   Using cached peewee-3.17.6.tar.gz (3.0 MB)
# done
# error
#   ERROR: Command errored out with exit status 1:
#    command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmpoclz8ovu
#        cwd: /tmp/pip-install-etsk6jlq/peewee_19c8875ac9bc40c6b833a099066f2992
#   Complete output (38 lines):
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#
#
#   # We define an xConnect function, but leave xCreate NULL so that the
#   # table-function can be called eponymously.
#   cdef int pwConnect(sqlite3 *db, void *pAux, int argc, const char *const*argv,
#                      sqlite3_vtab **ppVtab, char **pzErr) noexcept with gil:
#                                                          ^
#   ------------------------------------------------------------
#
#   playhouse/_sqlite_ext.pyx:389:56: Syntax error in C variable declaration
#   Compiling playhouse/_sqlite_ext.pyx because it depends on /databricks/python/lib/python3.9/site-packages/Cython/Includes/libc/string.pxd.
#   [1/1] Cythonizing playhouse/_sqlite_ext.pyx
#   Traceback (most recent call last):
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 349, in <module>
#       main()
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 331, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 117, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 177, in get_requires_for_build_wheel
#       return self._get_build_requires(
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 159, in _get_build_requires
#       self.run_setup()
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 174, in run_setup
#       exec(compile(code, __file__, 'exec'), locals())
#     File "setup.py", line 201, in <module>
#       _do_setup(extension_support, sqlite_extension_support)
#     File "setup.py", line 196, in _do_setup
#       ext_modules=cythonize(ext_modules))
#     File "/databricks/python/lib/python3.9/site-packages/Cython/Build/Dependencies.py", line 1127, in cythonize
#       cythonize_one(*args)
#     File "/databricks/python/lib/python3.9/site-packages/Cython/Build/Dependencies.py", line 1250, in cythonize_one
#       raise CompileError(None, pyx_file)
#   Cython.Compiler.Errors.CompileError: playhouse/_sqlite_ext.pyx
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/bd/be/e9c886b4601a19f4c34a1b75c5fe8b98a2115dd964251a76b24c977c369d/peewee-3.17.6.tar.gz#sha256=cea5592c6f4da1592b7cff8eaf655be6648a1f5857469e30037bf920c03fb8fb (from https://pypi.org/simple/peewee/). Command errored out with exit status 1: /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmpoclz8ovu Check the logs for full command output.
#   Using cached peewee-3.17.5.tar.gz (3.0 MB)
# done
# error
#   ERROR: Command errored out with exit status 1:
#    command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmpd8f_pdsv
#        cwd: /tmp/pip-install-etsk6jlq/peewee_171d268f6c1244c68288c57ce75a05bc
#   Complete output (38 lines):
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#
#
#   # We define an xConnect function, but leave xCreate NULL so that the
#   # table-function can be called eponymously.
#   cdef int pwConnect(sqlite3 *db, void *pAux, int argc, const char *const*argv,
#                      sqlite3_vtab **ppVtab, char **pzErr) noexcept with gil:
#                                                          ^
#   ------------------------------------------------------------
#
#   playhouse/_sqlite_ext.pyx:389:56: Syntax error in C variable declaration
#   Compiling playhouse/_sqlite_ext.pyx because it depends on /databricks/python/lib/python3.9/site-packages/Cython/Includes/libc/string.pxd.
#   [1/1] Cythonizing playhouse/_sqlite_ext.pyx
#   Traceback (most recent call last):
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 349, in <module>
#       main()
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 331, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 117, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 177, in get_requires_for_build_wheel
#       return self._get_build_requires(
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 159, in _get_build_requires
#       self.run_setup()
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 174, in run_setup
#       exec(compile(code, __file__, 'exec'), locals())
#     File "setup.py", line 201, in <module>
#       _do_setup(extension_support, sqlite_extension_support)
#     File "setup.py", line 196, in _do_setup
#       ext_modules=cythonize(ext_modules))
#     File "/databricks/python/lib/python3.9/site-packages/Cython/Build/Dependencies.py", line 1127, in cythonize
#       cythonize_one(*args)
#     File "/databricks/python/lib/python3.9/site-packages/Cython/Build/Dependencies.py", line 1250, in cythonize_one
#       raise CompileError(None, pyx_file)
#   Cython.Compiler.Errors.CompileError: playhouse/_sqlite_ext.pyx
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/1e/d4/22c2909b5a0b36e69471e699d673c2985f7691ca29870798a29e0a3d0e2b/peewee-3.17.5.tar.gz#sha256=e1b6a64192207fd3ddb4e1188054820f42aef0aadfa749e3981af3c119a76420 (from https://pypi.org/simple/peewee/). Command errored out with exit status 1: /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmpd8f_pdsv Check the logs for full command output.
#   Using cached peewee-3.17.3.tar.gz (3.0 MB)
# done
# error
#   ERROR: Command errored out with exit status 1:
#    command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmpqhqa7d9v
#        cwd: /tmp/pip-install-etsk6jlq/peewee_8ab40b304d2741b7a9107a41548ab31f
#   Complete output (40 lines):
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#
#
#   # We define an xConnect function, but leave xCreate NULL so that the
#   # table-function can be called eponymously.
#   cdef int pwConnect(sqlite3 *db, void *pAux, int argc, const char *const*argv,
#                      sqlite3_vtab **ppVtab, char **pzErr) noexcept with gil:
#                                                          ^
#   ------------------------------------------------------------
#
#   playhouse/_sqlite_ext.pyx:389:56: Syntax error in C variable declaration
#   Compiling playhouse/_sqlite_ext.pyx because it depends on /databricks/python/lib/python3.9/site-packages/Cython/Includes/libc/string.pxd.
#   [1/1] Cythonizing playhouse/_sqlite_ext.pyx
#   Traceback (most recent call last):
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 349, in <module>
#       main()
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 331, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 117, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 177, in get_requires_for_build_wheel
#       return self._get_build_requires(
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 159, in _get_build_requires
#       self.run_setup()
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 281, in run_setup
#       super(_BuildMetaLegacyBackend,
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 174, in run_setup
#       exec(compile(code, __file__, 'exec'), locals())
#     File "setup.py", line 196, in <module>
#       _do_setup(extension_support, sqlite_extension_support)
#     File "setup.py", line 191, in _do_setup
#       ext_modules=cythonize(ext_modules))
#     File "/databricks/python/lib/python3.9/site-packages/Cython/Build/Dependencies.py", line 1127, in cythonize
#       cythonize_one(*args)
#     File "/databricks/python/lib/python3.9/site-packages/Cython/Build/Dependencies.py", line 1250, in cythonize_one
#       raise CompileError(None, pyx_file)
#   Cython.Compiler.Errors.CompileError: playhouse/_sqlite_ext.pyx
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/7a/b1/2331e6b1fc8c61686dd9276f34142265462640eb0dd431246e30c4461065/peewee-3.17.3.tar.gz#sha256=ef15f90b628e41a584be8306cdc3243c51f73ce88b06154d9572f6d0284a0169 (from https://pypi.org/simple/peewee/). Command errored out with exit status 1: /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmpqhqa7d9v Check the logs for full command output.
#   Using cached peewee-3.17.2.tar.gz (938 kB)
# done
# error
#   ERROR: Command errored out with exit status 1:
#    command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmp9dkxu64a
#        cwd: /tmp/pip-install-etsk6jlq/peewee_18ac30c3cf194dcd979d758ab743bc86
#   Complete output (40 lines):
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#
#
#   # We define an xConnect function, but leave xCreate NULL so that the
#   # table-function can be called eponymously.
#   cdef int pwConnect(sqlite3 *db, void *pAux, int argc, const char *const*argv,
#                      sqlite3_vtab **ppVtab, char **pzErr) noexcept with gil:
#                                                          ^
#   ------------------------------------------------------------
#
#   playhouse/_sqlite_ext.pyx:389:56: Syntax error in C variable declaration
#   Compiling playhouse/_sqlite_ext.pyx because it depends on /databricks/python/lib/python3.9/site-packages/Cython/Includes/libc/string.pxd.
#   [1/1] Cythonizing playhouse/_sqlite_ext.pyx
#   Traceback (most recent call last):
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 349, in <module>
#       main()
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 331, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 117, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 177, in get_requires_for_build_wheel
#       return self._get_build_requires(
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 159, in _get_build_requires
#       self.run_setup()
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 281, in run_setup
#       super(_BuildMetaLegacyBackend,
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 174, in run_setup
#       exec(compile(code, __file__, 'exec'), locals())
#     File "setup.py", line 196, in <module>
#       _do_setup(extension_support, sqlite_extension_support)
#     File "setup.py", line 191, in _do_setup
#       ext_modules=cythonize(ext_modules))
#     File "/databricks/python/lib/python3.9/site-packages/Cython/Build/Dependencies.py", line 1127, in cythonize
#       cythonize_one(*args)
#     File "/databricks/python/lib/python3.9/site-packages/Cython/Build/Dependencies.py", line 1250, in cythonize_one
#       raise CompileError(None, pyx_file)
#   Cython.Compiler.Errors.CompileError: playhouse/_sqlite_ext.pyx
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/35/6d/54848039cd02f4aca217855570e8300a64d933f9791443aa3d7c02ecc901/peewee-3.17.2.tar.gz#sha256=2fe35224317d6b50e162ac44880a0d281d4ac0d53c7ae9d228eb769299618fb1 (from https://pypi.org/simple/peewee/). Command errored out with exit status 1: /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmp9dkxu64a Check the logs for full command output.
#   Using cached peewee-3.17.1.tar.gz (3.0 MB)
# done
# error
#   ERROR: Command errored out with exit status 1:
#    command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmptgw28on0
#        cwd: /tmp/pip-install-etsk6jlq/peewee_d305d42658674067be220dbf2fb47149
#   Complete output (40 lines):
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#
#
#   # We define an xConnect function, but leave xCreate NULL so that the
#   # table-function can be called eponymously.
#   cdef int pwConnect(sqlite3 *db, void *pAux, int argc, const char *const*argv,
#                      sqlite3_vtab **ppVtab, char **pzErr) noexcept with gil:
#                                                          ^
#   ------------------------------------------------------------
#
#   playhouse/_sqlite_ext.pyx:389:56: Syntax error in C variable declaration
#   Compiling playhouse/_sqlite_ext.pyx because it depends on /databricks/python/lib/python3.9/site-packages/Cython/Includes/libc/string.pxd.
#   [1/1] Cythonizing playhouse/_sqlite_ext.pyx
#   Traceback (most recent call last):
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 349, in <module>
#       main()
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 331, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 117, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 177, in get_requires_for_build_wheel
#       return self._get_build_requires(
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 159, in _get_build_requires
#       self.run_setup()
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 281, in run_setup
#       super(_BuildMetaLegacyBackend,
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 174, in run_setup
#       exec(compile(code, __file__, 'exec'), locals())
#     File "setup.py", line 196, in <module>
#       _do_setup(extension_support, sqlite_extension_support)
#     File "setup.py", line 191, in _do_setup
#       ext_modules=cythonize(ext_modules))
#     File "/databricks/python/lib/python3.9/site-packages/Cython/Build/Dependencies.py", line 1127, in cythonize
#       cythonize_one(*args)
#     File "/databricks/python/lib/python3.9/site-packages/Cython/Build/Dependencies.py", line 1250, in cythonize_one
#       raise CompileError(None, pyx_file)
#   Cython.Compiler.Errors.CompileError: playhouse/_sqlite_ext.pyx
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/8d/a5/89cdbc4a7f6d7a0624c120be102db770ee717aa371066581e3daf2beb96f/peewee-3.17.1.tar.gz#sha256=e009ac4227c4fdc0058a56e822ad5987684f0a1fbb20fed577200785102581c3 (from https://pypi.org/simple/peewee/). Command errored out with exit status 1: /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmptgw28on0 Check the logs for full command output.
#   Using cached peewee-3.17.0.tar.gz (2.9 MB)
# done
# error
#   ERROR: Command errored out with exit status 1:
#    command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmpi1t1fg0i
#        cwd: /tmp/pip-install-etsk6jlq/peewee_ea51bc0f25e846748e2b66c86ddf4e08
#   Complete output (40 lines):
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#
#
#   # We define an xConnect function, but leave xCreate NULL so that the
#   # table-function can be called eponymously.
#   cdef int pwConnect(sqlite3 *db, void *pAux, int argc, const char *const*argv,
#                      sqlite3_vtab **ppVtab, char **pzErr) noexcept with gil:
#                                                          ^
#   ------------------------------------------------------------
#
#   playhouse/_sqlite_ext.pyx:389:56: Syntax error in C variable declaration
#   Compiling playhouse/_sqlite_ext.pyx because it depends on /databricks/python/lib/python3.9/site-packages/Cython/Includes/libc/string.pxd.
#   [1/1] Cythonizing playhouse/_sqlite_ext.pyx
#   Traceback (most recent call last):
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 349, in <module>
#       main()
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 331, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 117, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 177, in get_requires_for_build_wheel
#       return self._get_build_requires(
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 159, in _get_build_requires
#       self.run_setup()
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 281, in run_setup
#       super(_BuildMetaLegacyBackend,
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 174, in run_setup
#       exec(compile(code, __file__, 'exec'), locals())
#     File "setup.py", line 196, in <module>
#       _do_setup(extension_support, sqlite_extension_support)
#     File "setup.py", line 191, in _do_setup
#       ext_modules=cythonize(ext_modules))
#     File "/databricks/python/lib/python3.9/site-packages/Cython/Build/Dependencies.py", line 1127, in cythonize
#       cythonize_one(*args)
#     File "/databricks/python/lib/python3.9/site-packages/Cython/Build/Dependencies.py", line 1250, in cythonize_one
#       raise CompileError(None, pyx_file)
#   Cython.Compiler.Errors.CompileError: playhouse/_sqlite_ext.pyx
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/6a/30/a727bb1420076b3c14b60911d111f0fc0449d31a1123a1ad18878a7a4e40/peewee-3.17.0.tar.gz#sha256=3a56967f28a43ca7a4287f4803752aeeb1a57a08dee2e839b99868181dfb5df8 (from https://pypi.org/simple/peewee/). Command errored out with exit status 1: /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmpi1t1fg0i Check the logs for full command output.
#   Using cached peewee-3.16.3.tar.gz (928 kB)
# done
# error
#   ERROR: Command errored out with exit status 1:
#    command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmpbysozvss
#        cwd: /tmp/pip-install-etsk6jlq/peewee_54c876cd4fd146058784bfbc113a5bee
#   Complete output (40 lines):
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#
#
#   # We define an xConnect function, but leave xCreate NULL so that the
#   # table-function can be called eponymously.
#   cdef int pwConnect(sqlite3 *db, void *pAux, int argc, const char *const*argv,
#                      sqlite3_vtab **ppVtab, char **pzErr) noexcept with gil:
#                                                          ^
#   ------------------------------------------------------------
#
#   playhouse/_sqlite_ext.pyx:389:56: Syntax error in C variable declaration
#   Compiling playhouse/_sqlite_ext.pyx because it depends on /databricks/python/lib/python3.9/site-packages/Cython/Includes/libc/string.pxd.
#   [1/1] Cythonizing playhouse/_sqlite_ext.pyx
#   Traceback (most recent call last):
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 349, in <module>
#       main()
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 331, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 117, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 177, in get_requires_for_build_wheel
#       return self._get_build_requires(
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 159, in _get_build_requires
#       self.run_setup()
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 281, in run_setup
#       super(_BuildMetaLegacyBackend,
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 174, in run_setup
#       exec(compile(code, __file__, 'exec'), locals())
#     File "setup.py", line 196, in <module>
#       _do_setup(extension_support, sqlite_extension_support)
#     File "setup.py", line 191, in _do_setup
#       ext_modules=cythonize(ext_modules))
#     File "/databricks/python/lib/python3.9/site-packages/Cython/Build/Dependencies.py", line 1127, in cythonize
#       cythonize_one(*args)
#     File "/databricks/python/lib/python3.9/site-packages/Cython/Build/Dependencies.py", line 1250, in cythonize_one
#       raise CompileError(None, pyx_file)
#   Cython.Compiler.Errors.CompileError: playhouse/_sqlite_ext.pyx
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/e2/1e/6455dc3c759af3e565414985c5c6f845d3e5f83bbf4a24cdd0aef9cc3f83/peewee-3.16.3.tar.gz#sha256=12b30e931193bc37b11f7c2ac646e3f67125a8b1a543ad6ab37ad124c8df7d16 (from https://pypi.org/simple/peewee/). Command errored out with exit status 1: /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmpbysozvss Check the logs for full command output.
#   Using cached peewee-3.16.2.tar.gz (2.9 MB)
# done
# error
#   ERROR: Command errored out with exit status 1:
#    command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmpuokec4ck
#        cwd: /tmp/pip-install-etsk6jlq/peewee_4439a78947864a569ef3cf2c5108d8f1
#   Complete output (40 lines):
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#       def autocommit(self):
#           if self.conn.initialized and self.conn.db:
#               return sqlite3_get_autocommit(self.conn.db) != 0
#
#
#   cdef int _commit_callback(void *userData) noexcept with gil:
#                                            ^
#   ------------------------------------------------------------
#
#   playhouse/_sqlite_ext.pyx:1511:42: Syntax error in C variable declaration
#   Compiling playhouse/_sqlite_ext.pyx because it depends on /databricks/python/lib/python3.9/site-packages/Cython/Includes/libc/string.pxd.
#   [1/1] Cythonizing playhouse/_sqlite_ext.pyx
#   Traceback (most recent call last):
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 349, in <module>
#       main()
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 331, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py", line 117, in get_requires_for_build_wheel
#       return hook(config_settings)
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 177, in get_requires_for_build_wheel
#       return self._get_build_requires(
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 159, in _get_build_requires
#       self.run_setup()
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 281, in run_setup
#       super(_BuildMetaLegacyBackend,
#     File "/databricks/python/lib/python3.9/site-packages/setuptools/build_meta.py", line 174, in run_setup
#       exec(compile(code, __file__, 'exec'), locals())
#     File "setup.py", line 196, in <module>
#       _do_setup(extension_support, sqlite_extension_support)
#     File "setup.py", line 191, in _do_setup
#       ext_modules=cythonize(ext_modules))
#     File "/databricks/python/lib/python3.9/site-packages/Cython/Build/Dependencies.py", line 1127, in cythonize
#       cythonize_one(*args)
#     File "/databricks/python/lib/python3.9/site-packages/Cython/Build/Dependencies.py", line 1250, in cythonize_one
#       raise CompileError(None, pyx_file)
#   Cython.Compiler.Errors.CompileError: playhouse/_sqlite_ext.pyx
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a9/50/1dd5ea74c559df4afb8391f8d05f0fec685dbe8effba13bb9072901eb288/peewee-3.16.2.tar.gz#sha256=10769981198c7311f84a0ca8db892fa213303a8eb1305deb795a71e7bd606a91 (from https://pypi.org/simple/peewee/). Command errored out with exit status 1: /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmpuokec4ck Check the logs for full command output.
# Collecting yfinance
#   Using cached yfinance-0.2.44-py2.py3-none-any.whl (94 kB)
#   Using cached yfinance-0.2.43-py2.py3-none-any.whl (84 kB)
#   Using cached yfinance-0.2.42-py2.py3-none-any.whl (84 kB)
#   Using cached yfinance-0.2.41-py2.py3-none-any.whl (73 kB)
#   Using cached yfinance-0.2.40-py2.py3-none-any.whl (73 kB)
#   Using cached yfinance-0.2.39-py2.py3-none-any.whl (73 kB)
#   Using cached yfinance-0.2.38-py2.py3-none-any.whl (72 kB)
# Collecting appdirs>=1.4.4
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting yfinance
#   Using cached yfinance-0.2.37-py2.py3-none-any.whl (72 kB)
#   Using cached yfinance-0.2.36-py2.py3-none-any.whl (72 kB)
#   Using cached yfinance-0.2.35-py2.py3-none-any.whl (72 kB)
#   Using cached yfinance-0.2.34-py2.py3-none-any.whl (72 kB)
#   Using cached yfinance-0.2.33-py2.py3-none-any.whl (69 kB)
#   Using cached yfinance-0.2.32-py2.py3-none-any.whl (68 kB)
#   Using cached yfinance-0.2.31-py2.py3-none-any.whl (65 kB)
#   Using cached yfinance-0.2.30-py2.py3-none-any.whl (65 kB)
#   Using cached yfinance-0.2.29-py2.py3-none-any.whl (65 kB)
#   Using cached yfinance-0.2.28-py2.py3-none-any.whl (65 kB)
# Requirement already satisfied: numpy>=1.16.5 in /databricks/python3/lib/python3.9/site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: soupsieve>1.2 in /databricks/python3/lib/python3.9/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: six>=1.9 in /databricks/python3/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /databricks/python3/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /databricks/python3/lib/python3.9/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.9/site-packages (from requests>=2.31->yfinance) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.9/site-packages (from requests>=2.31->yfinance) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.9/site-packages (from requests>=2.31->yfinance) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.9/site-packages (from requests>=2.31->yfinance) (2.0.4)
# Installing collected packages: pytz, requests, multitasking, lxml, html5lib, frozendict, appdirs, yfinance
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2021.3
#     Not uninstalling pytz at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de
#     Can't uninstall 'pytz'. No files were found to uninstall.
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Not uninstalling requests at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de
#     Can't uninstall 'requests'. No files were found to uninstall.
# Successfully installed appdirs-1.4.4 frozendict-2.4.6 html5lib-1.1 lxml-5.3.0 multitasking-0.0.11 pytz-2024.2 requests-2.32.3 yfinance-0.2.28
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /databricks/python3/lib/python3.9/site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /databricks/python3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in /databricks/python3/lib/python3.9/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/lib/python3.9/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /databricks/python3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.9/site-packages (1.21.5)
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /databricks/python3/lib/python3.9/site-packages (3.5.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /databricks/python3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in /databricks/python3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.17 in /databricks/python3/lib/python3.9/site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /databricks/python3/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in /databricks/python3/lib/python3.9/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in /databricks/python3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: six>=1.5 in /databricks/python3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-3ea32754-26c1-4751-9567-6041da7bf5de/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import yfinance as yf

# %% [markdown]
# ## Sets

# %%
data_inicial = '2019-01-01'
data_final = '2024-12-31'


# filter_acoes.split(',')

acoes = filter_acoes.split(',')

# %% [markdown]
# ## Get

# %%
df_acoes = pd.DataFrame(columns=['Open','High','Low','Close','Adj Close','Volume'])


for acao in acoes:
    # print(acao)
    tabela_cotacoes = yf.download(acao, start=data_inicial, end=data_final)
    
    tabela_cotacoes['codigo'] = acao
    tabela_cotacoes = tabela_cotacoes.reset_index()

    for media_movel in ["10","30","60","90","120"]:
        print(media_movel)
        tabela_cotacoes[f'media_movel_{media_movel}d'] = tabela_cotacoes['Close'].rolling(int(media_movel)).mean()

    # print(tabela_cotacoes.columns)
    df_acoes = pd.concat([tabela_cotacoes,df_acoes],axis=0)

    # print(tabela_cotacoes.info)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 10
# 30
# 60
# 90
# 120
# [*********************100%%**********************]  1 of 1 completed
# 10
# 30
# 60
# 90
# 120
# [*********************100%%**********************]  1 of 1 completed
# 10
# 30
# 60
# 90
# 120
# [*********************100%%**********************]  1 of 1 completed
# 10
# 30
# 60
# 90
# 120

# %%
spark.createDataFrame(df_acoes).createOrReplaceTempView('acoes_analise')

# %%
colunas = 'Date::date,codigo,round(open,2) as abertura, round(close,2) as Fechamento, round(open,2) - round(close,2) as diff'

for media_movel in ["10","30","60","90","120"]:
        colunas = colunas + f',round(media_movel_{media_movel}d,2) as media_movel_{media_movel}d'

print(colunas)

display(spark.sql(f'select {colunas} from  acoes_analise ORDER BY Date::date'))
# Out:
# Date::date,codigo,round(open,2) as abertura, round(close,2) as Fechamento, round(open,2) - round(close,2) as diff,round(media_movel_10d,2) as media_movel_10d,round(media_movel_30d,2) as media_movel_30d,round(media_movel_60d,2) as media_movel_60d,round(media_movel_90d,2) as media_movel_90d,round(media_movel_120d,2) as media_movel_120d
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Date</th><th>codigo</th><th>abertura</th><th>Fechamento</th><th>diff</th><th>media_movel_10d</th><th>media_movel_30d</th><th>media_movel_60d</th><th>media_movel_90d</th><th>media_movel_120d</th></tr></thead><tbody><tr><td>2019-01-02</td><td>RAPT4.SA</td><td>9.14</td><td>9.46</td><td>-0.3200000000000003</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-02</td><td>WEGE3.SA</td><td>8.81</td><td>8.99</td><td>-0.17999999999999972</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-02</td><td>TUPY3.SA</td><td>20.33</td><td>20.51</td><td>-0.18000000000000327</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-02</td><td>POMO4.SA</td><td>4.07</td><td>4.24</td><td>-0.16999999999999993</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-03</td><td>RAPT4.SA</td><td>9.44</td><td>9.46</td><td>-0.02000000000000135</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-03</td><td>WEGE3.SA</td><td>9.0</td><td>9.19</td><td>-0.1899999999999995</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-03</td><td>TUPY3.SA</td><td>20.51</td><td>20.31</td><td>0.20000000000000284</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-03</td><td>POMO4.SA</td><td>4.24</td><td>4.25</td><td>-0.009999999999999787</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-04</td><td>RAPT4.SA</td><td>9.5</td><td>9.5</td><td>0.0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-04</td><td>WEGE3.SA</td><td>9.2</td><td>9.3</td><td>-0.10000000000000142</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-04</td><td>TUPY3.SA</td><td>20.5</td><td>20.32</td><td>0.17999999999999972</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-04</td><td>POMO4.SA</td><td>4.26</td><td>4.3</td><td>-0.040000000000000036</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-07</td><td>RAPT4.SA</td><td>9.49</td><td>9.62</td><td>-0.129999999999999</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-07</td><td>WEGE3.SA</td><td>9.38</td><td>9.15</td><td>0.23000000000000043</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-07</td><td>TUPY3.SA</td><td>20.28</td><td>20.49</td><td>-0.2099999999999973</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-07</td><td>POMO4.SA</td><td>4.3</td><td>4.29</td><td>0.009999999999999787</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-08</td><td>RAPT4.SA</td><td>9.65</td><td>9.45</td><td>0.20000000000000107</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-08</td><td>WEGE3.SA</td><td>9.19</td><td>9.08</td><td>0.10999999999999943</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-08</td><td>TUPY3.SA</td><td>20.53</td><td>20.7</td><td>-0.16999999999999815</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-08</td><td>POMO4.SA</td><td>4.31</td><td>4.19</td><td>0.11999999999999922</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-09</td><td>RAPT4.SA</td><td>9.54</td><td>9.62</td><td>-0.08000000000000007</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-09</td><td>WEGE3.SA</td><td>9.08</td><td>9.18</td><td>-0.09999999999999964</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>2019-01-09</td><td>TUPY3.SA</td><td>20.7</td><td>20.98 ...
# Databricks visualization. Run in Databricks to view.

# %%
# %sql

Select Date::date,codigo,open as abertura, close as Fechamento,  round(open,2) - round(close,2) as diff  from acoes_analise
order by 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Date</th><th
td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
with datas as (
Select
  min(Date::date) as primeira_cotacao_ano,
  max(Date::date) as ultima_cotacao_ano
from
  acoes_analise
WHERE
  YEAR(Date::date) = year(current_date())),
pega_valores as  
(select 
  case when acoes.date::date = datas.primeira_cotacao_ano then acoes.open else 0 end as abertura,
  case when acoes.date::date = datas.ultima_cotacao_ano then acoes.open else 0 end as fechamento
from  acoes_analise acoes
inner join datas datas on datas.primeira_cotacao_ano = acoes.date::date or datas.ultima_cotacao_ano = acoes.date::date 
)
select sum(abertura) as abertura,sum(fechamento) as fechamento,sum(fechamento) -sum(abertura) as lucro_ano  from pega_valores
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>abertura</th><th>fechamento</th><th>lucro_ano</th></tr></thead><tbody><tr><td>85.46000003814697</td><td>100.96000003814697</td><td>15.5</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.
# Databricks visualization. Run in Databricks to view.

# %%
df_dividends = pd.DataFrame(columns=['Open','High','Low','Close','Adj Close','Volume'])


for acao in acoes:
    # print(acao)
    # tabela_dividends = yf.download(acao, start=data_inicial, end=data_final)

    tabela_dividends = yf.Ticker(acao).history(period="max")

    tabela_dividends['codigo'] = acao
    tabela_dividends = tabela_dividends.reset_index()

    # print(tabela_cotacoes.columns)
    df_dividends = pd.concat([df_dividends,tabela_dividends],axis=0)

    # print(tabela_cotacoes.info)

# %%
spark.createDataFrame(df_dividends.reset_index()).createOrReplaceTempView('dividendos')

# %%
# %sql


select sum(dividends) from dividendos where year(Date::date) = year(current_date()) 
group by all
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sum(dividends)</th></tr></thead><tbody><tr><td>1.6509030000000002</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
# %sql


select sum(dividends) from dividendos where year(Date::date) = year(current_date())-1 
group by all
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sum(dividends)</th></tr></thead><tbody><tr><td>2.992345</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
# %sql


select sum(dividends) from dividendos where date::date between date_trunc('YEAR',date_add(current_date(),-365))::date and  date_add(current_date()-1, -366)
group by all
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sum(dividends)</th></tr></thead><tbody><tr><td>2.214758</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
select
  sum(dividends),
  month(date :: date),
  year(date :: date),
  concat(month(date :: date),'/',year(date :: date)) as ref
from
  dividendos
where
  (date::date between date_trunc('YEAR', date_add(current_date(), -365)) :: date  and date_add(current_date() -1, -366) or 
  year(date::date) =   year(current_date()))

  and dividends > 0 

group by
  all
order by
  3,
  2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sum(dividends)</th><th>month(date)</th><th>year(date)</th><th>ref</th></tr></thead><tbody><tr><td>0.226762</td><td>1</td><td>2023</td><td>1/2023</td></tr><tr><td>0.226304</td><td>2</td><td>2023</td><td>2/2023</td></tr><tr><td>0.129902</td><td>3</td><td>2023</td><td>3/2023</td></tr><tr><td>0.741451</td><td>5</td><td>2023</td><td>5/2023</td></tr><tr><td>0.058294</td><td>6</td><td>2023</td><td>6/2023</td></tr><tr><td>0.42593499999999995</td><td>7</td><td>2023</td><td>7/2023</td></tr><tr><td>0.322777</td><td>9</td><td>2023</td><td>9/2023</td></tr><tr><td>0.083333</td><td>10</td><td>2023</td><td>10/2023</td></tr><tr><td>0.255427</td><td>1</td><td>2024</td><td>1/2024</td></tr><tr><td>0.297943</td><td>2</td><td>2024</td><td>2/2024</td></tr><tr><td>0.249432</td><td>3</td><td>2024</td><td>3/2024</td></tr><tr><td>0.253465</td><td>5</td><td>2024</td><td>5/2024</td></tr><tr><td>0.21702500000000002</td><td>7</td><td>2024</td><td>7/2024</td></tr><tr><td>0.307552</td><td>8</td><td>2024</td><td>8/2024</td></tr><tr><td>0.070059</td><td>9</td><td>2024</td><td>9/2024</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
df_teste = spark.sql('select *  from dividendos where date::date =  (select max(date::date) from dividendos)')
